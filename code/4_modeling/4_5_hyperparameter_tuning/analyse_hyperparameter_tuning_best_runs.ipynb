# %% [markdown]
# # Analyse best runs in the hyperparameter process

# %%
import pandas as pd

# TODO: Change to new feolder and use wandb for taking metrics
# TODO: Add also csv with best runs to see it for laters

# %% [markdown]
# ## 1. Hyperparameter tuning for Random Forest

# %%
# load existing results from the hyperparameter tuning process
results_csv_rf = "rf_grid_search_results.csv"
existing_df = pd.read_csv(results_csv_rf)

# show best twenty results
existing_df.sort_values("f1_macro_score", ascending=False).head(30)
# Out:
#       bootstrap  max_depth  min_samples_leaf  min_samples_split  n_estimators  \
# 1611      False        NaN                 1                  2          1500
# 1609      False        NaN                 1                  2          1200
# 1610      False        NaN                 1                  2          1400
# 1608      False        NaN                 1                  2          1000
# 1607      False        NaN                 1                  2           750
# 1600      False        NaN                 1                  2           250
# 1604      False        NaN                 1                  2           450
# 1603      False        NaN                 1                  2           400
# 1602      False        NaN                 1                  2           350
# 977       False      200.0                 1                  2           200
# 602       False        NaN                 1                  2           200
# ...

# %% [markdown]
# ## 2. Hyperparameter tuning for XGBoost

# %%
# load existing results from the hyperparameter tuning process
results_csv_rf = "xgboost_hyperopt_results.csv"
existing_df = pd.read_csv(results_csv_rf)

# show best twenty results
existing_df.sort_values("f1_macro_score", ascending=False).head(20)
# Out:
#      colsample_bylevel  colsample_bytree     gamma  learning_rate  max_depth  \
# 301           0.772713          0.580679  0.008083       0.040281          9
# 285           0.803427          0.914025  0.107827       0.083648          9
# 372           0.959086          0.591527  0.007456       0.162901          6
# 284           0.805117          0.999295  0.105038       0.082467          9
# 309           0.655665          0.579482  0.005809       0.063579          6
# 282           0.830648          0.999265  0.071238       0.072266          9
# 287           0.753473          0.906502  0.086556       0.097558          9
# 253           0.626666          0.748897  0.015833       0.089032          9
# 386           0.843551          0.592353  0.053866       0.115968          9
# 374           0.999911          0.591473  0.008271       0.289972          6
# 283           0.825671          0.973577  0.088799       0.072833          9
# ...
